# %% [markdown]
# <a href="https://colab.research.google.com/github/tusharm78/A2AWalkthrough/blob/main/Sales_Project_SparkCluster_TestLab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#step1
# !pip install findspark pyspark

#step2
import findspark
findspark.init()

#step3
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName('tusharapp').getOrCreate()

# %%
sales = spark.read.format("csv").option("header", "true").option("inferSchema", "true").load("/content/sales_transactions2.txt")

#Verify how many rows are there

sales.count()
# Out:
# 100
